# %% [markdown]
# ## VIRTUAL KEYBOARD

# %%
from tkinter import *
imaginary=Tk()
imaginary.title("Mehuly")
a1=Label(text="VIRTUAL KEYBOARD")
a1.pack()
def num1():
    print("1",end="")
def num2():
    print("2",end="")
def num3():
    print("3",end="")
def num4():
    print("4",end="")
def num5():
    print("5",end="")
def num6():
    print("6",end="")
def num7():
    print("7",end="")
def num8():
    print("8",end="")
def num9():
    print("9",end="")
def num10():
    print("0",end="")
def space():
    print(" ",end="")
def enter():
    print()
def a():
    print("A",end="")
def b():
    print("B",end="")
def c():
    print("C",end="")
def d():
    print("D",end="")
def e():
    print("E",end="")
def f():
    print("F",end="")
def g():
    print("G",end="")
def h():
    print("H",end="")
def i():
    print("I",end="")
def j():
    print("J",end="")
def k():
    print("K",end="")
def l():
    print("L",end="")
def m():
    print("M",end="")
def n():
    print("N",end="")
def o():
    print("O",end="")
def p():
    print("P",end="")
def q():
    print("Q",end="")
def r():
    print("R",end="")
def s():
    print("S",end="")
def t():
    print("T",end="")
def u():
    print("U",end="")
def v():
    print("V",end="")
def w():
    print("W",end="")
def x():
    print("X",end="")
def y():
    print("Y",end="")
def z():
    print("Z",end="")    
def comma():
    print(",",end="")
def fullstop():
    print(".",end="")
def slash():
    print("/",end="")
f1=Frame(imaginary,borderwidth=6,bg='grey',relief=RIDGE)
f1.pack()
b_1=Button(f1,text="1",width=10,command=num1)
b_2=Button(f1,text="2",width=10,command=num2)
b_3=Button(f1,text="3",width=10,command=num3)
b_4=Button(f1,text="4",width=10,command=num4)
b_5=Button(f1,text="5",width=10,command=num5)
b_6=Button(f1,text="6",width=10,command=num6)
b_7=Button(f1,text="7",width=10,command=num7)
b_8=Button(f1,text="8",width=10,command=num8)
b_9=Button(f1,text="9",width=10,command=num9)
b_10=Button(f1,text="0",width=10,command=num10)
b1=Button(f1,text="Q",width=10,command=q)
b2=Button(f1,text="W",width=10,command=w)
b3=Button(f1,text="E",width=10,command=e)
b4=Button(f1,text="R",width=10,command=r)
b5=Button(f1,text="T",width=10,command=t)
b6=Button(f1,text="Y",width=10,command=y)
b7=Button(f1,text="U",width=10,command=u)
b8=Button(f1,text="I",width=10,command=i)
b9=Button(f1,text="O",width=10,command=o)
b10=Button(f1,text="P",width=10,command=p)
b11=Button(f1,text="A",width=10,command=a)
b12=Button(f1,text="S",width=10,command=s)
b13=Button(f1,text="D",width=10,command=d)
b14=Button(f1,text="F",width=10,command=f)
b15=Button(f1,text="G",width=10,command=g)
b16=Button(f1,text="H",width=10,command=h)
b17=Button(f1,text="J",width=10,command=j)
b18=Button(f1,text="K",width=10,command=k)
b19=Button(f1,text="L",width=10,command=l)
b_en=Button(f1,text="ENTER",width=10,command=enter)
b20=Button(f1,text="/",width=10,command=slash)
b21=Button(f1,text="Z",width=10,command=z)
b22=Button(f1,text="X",width=10,command=x)
b23=Button(f1,text="C",width=10,command=c)
b24=Button(f1,text="V",width=10,command=v)
b25=Button(f1,text="B",width=10,command=b)
b26=Button(f1,text="N",width=10,command=n)
b27=Button(f1,text="M",width=10,command=m)
b28=Button(f1,text=",",width=10,command=comma)
b29=Button(f1,text=".",width=10,command=fullstop)
b_space=Button(f1,text=" ",width=10,command=space)
b_1.grid(column=0,row=0)
b_2.grid(column=1,row=0)
b_3.grid(column=2,row=0)
b_4.grid(column=3,row=0)
b_5.grid(column=4,row=0)
b_6.grid(column=5,row=0)
b_7.grid(column=6,row=0)
b_8.grid(column=7,row=0)
b_9.grid(column=8,row=0)
b_10.grid(column=9,row=0)
b1.grid(column=0,row=1)
b2.grid(column=1,row=1)
b3.grid(column=2,row=1)
b4.grid(column=3,row=1)
b5.grid(column=4,row=1)
b6.grid(column=5,row=1)
b7.grid(column=6,row=1)
b8.grid(column=7,row=1)
b9.grid(column=8,row=1)
b10.grid(column=9,row=1)
b11.grid(column=0,row=2)
b12.grid(column=1,row=2)
b13.grid(column=2,row=2)
b14.grid(column=3,row=2)
b15.grid(column=4,row=2)
b16.grid(column=5,row=2)
b17.grid(column=6,row=2)
b18.grid(column=7,row=2)
b19.grid(column=8,row=2)
b_en.grid(column=9,row=2)
b20.grid(column=0,row=3)
b21.grid(column=1,row=3)
b22.grid(column=2,row=3)
b23.grid(column=3,row=3)
b24.grid(column=4,row=3)
b25.grid(column=5,row=3)
b26.grid(column=6,row=3)
b27.grid(column=7,row=3)
b28.grid(column=8,row=3)
b29.grid(column=9,row=3)
b_space.grid(column=4,row=4)
imaginary.mainloop()
# Out:
# HELLO.
# WELCOME TO THIS PROJECT OF VIRTUAL KEYBOARD.
